# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 31.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO  # or if the YOLOv10 repo uses custom class, adjust accordingly

model = YOLO("weights/yolov10n.pt")  # or yolov10s, yolov10m etc

model.train(
    data="/content/drive/MyDrive/dataset/data1.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    device="0"  # GPU index
)
# Out:
# Ultralytics 8.3.221 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
